# %%
import pandas as pd

# %%
#This is using data from the merged files from the NBA_dataaccess fileset
df = pd.read_csv('merged_df.csv')
# Out:
#           GAME_ID   GAME_DATE     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  \
# 0        22201191  2023-04-05  1610612764               WAS  Washington
# 1        22201191  2023-04-05  1610612764               WAS  Washington
# 2        22201191  2023-04-05  1610612764               WAS  Washington
# 3        22201191  2023-04-05  1610612764               WAS  Washington
# 4        22201191  2023-04-05  1610612764               WAS  Washington
# ...           ...         ...         ...               ...         ...
# 21368  1522200006  2022-07-08  1610612749               MIL   Milwaukee
# 21369  1522200006  2022-07-08  1610612749               MIL   Milwaukee
# 21370  1522200006  2022-07-08  1610612749               MIL   Milwaukee
# 21371  1522200006  2022-07-08  1610612749               MIL   Milwaukee
# 21372  1522200006  2022-07-08  1610612749               MIL   Milwaukee
#
#        PLAYER_ID        PLAYER_NAME   PTS   REB  STL  AST   TO  BLK   FGA  \
# ...

# %%
#This code was used to find the player position and other details from the NBA data file

selected_cols = ['PLAYER_ID', 'START_POSITION','TEAM_CITY']
df = df[selected_cols]
df = df.dropna()
df
# Out:
#        PLAYER_ID START_POSITION   TEAM_CITY
# 0        1630557              F  Washington
# 1        1630264              F  Washington
# 2        1629655              C  Washington
# 3        1631098              G  Washington
# 4        1630692              G  Washington
# ...          ...            ...         ...
# 21357    1630699              F   Milwaukee
# 21358    1630572              F   Milwaukee
# 21359    1629608              C   Milwaukee
# 21360    1629730              G   Milwaukee
# 21361    1630492              G   Milwaukee
#
# [8219 rows x 3 columns]

# %% [markdown]
# # Atlanta vs. Dallas

# %%
#Using the output of the modeling analysis, for each team we are only predicting and aggregating the starting score. This was done for each team.


atl = pd.read_csv('FInal Files/ATL_DALVSATL_GAMEID22201167.csv')
atl
# Out:
#        TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred       TOTAL
# 0   1610612737     203991       Clint Capela   9.427203  115.787658
# 1   1610612737     203992  Bogdan Bogdanovic   9.844227  115.787658
# 2   1610612737    1627749    Dejounte Murray  10.412616  115.787658
# 3   1610612737    1628381       John Collins  22.443116  115.787658
# 4   1610612737    1628988      Aaron Holiday   4.733938  115.787658
# 5   1610612737    1629027         Trae Young  20.914669  115.787658
# 6   1610612737    1629631    De'Andre Hunter  12.878921  115.787658
# 7   1610612737    1630168     Onyeka Okongwu   3.682940  115.787658
# 8   1610612737    1630180         Saddiq Bey   9.164724  115.787658
# 9   1610612737    1630235      Trent Forrest   6.285302  115.787658
# 10  1610612737    1630552      Jalen Johnson   6.000000  115.787658

# %%
merged = atl.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
new_df = new_df.drop('TOTAL', axis=1)
new_df
# Out:
#         TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612737     203991       Clint Capela   9.427203              C
# 62   1610612737     203992  Bogdan Bogdanovic   9.844227              F
# 71   1610612737    1627749    Dejounte Murray  10.412616              G
# 144  1610612737    1628381       John Collins  22.443116              F
# 214  1610612737    1628988      Aaron Holiday   4.733938              G
# 219  1610612737    1629027         Trae Young  20.914669              G
# 291  1610612737    1629631    De'Andre Hunter  12.878921              F
# 356  1610612737    1630168     Onyeka Okongwu   3.682940              C
# 373  1610612737    1630180         Saddiq Bey   9.164724              F
# 392  1610612737    1630235      Trent Forrest   6.285302              G
# 395  1610612737    1630552      Jalen Johnson   6.000000              F
#
#     TEAM_CITY
# 0     Atlanta
# 62    Atlanta
# 71    Atlanta
# 144   Atlanta
# 214   Atlanta
# ...

# %%
atl_selected_players = ['Trae Young', 'Dejounte Murray','Saddiq Bey','John Collins','Clint Capela']
atl_filtered_df = new_df[new_df['PLAYER_NAME'].isin(selected_players)]
atl_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID      PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612737     203991     Clint Capela   9.427203              C
# 71   1610612737    1627749  Dejounte Murray  10.412616              G
# 144  1610612737    1628381     John Collins  22.443116              F
# 219  1610612737    1629027       Trae Young  20.914669              G
# 373  1610612737    1630180       Saddiq Bey   9.164724              F
#
#     TEAM_CITY
# 0     Atlanta
# 71    Atlanta
# 144   Atlanta
# 219   Atlanta
# 373   Atlanta

# %%
atl_filtered_df['PTS_pred'].sum()
# Out:
# 72.3623293798747

# %%
dal = pd.read_csv('FInal Files/DAL_DALVSATL_GAMEID22201167.csv')

# %%
merged = dal.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
new_df = new_df.drop('TOTAL', axis=1)
new_df
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612742     201580      JaVale McGee   8.640660              C
# 7    1610612742     202681      Kyrie Irving  24.365069              G
# 66   1610612742     202693   Markieff Morris  13.530322              F
# 67   1610612742     203200    Justin Holiday   8.107163              F
# 69   1610612742     203493    Reggie Bullock   9.552493              F
# 122  1610612742     203501  Tim Hardaway Jr.  17.469229              F
# 166  1610612742     203939     Dwight Powell   7.004571              C
# 228  1610612742    1626174    Christian Wood   7.644775              F
# 245  1610612742    1628373   Frank Ntilikina   3.383053              G
# 248  1610612742    1628467       Maxi Kleber   9.643977              F
# 253  1610612742    1629029       Luka Doncic  21.868238              G
# 317  1610612742    1630182        Josh Green   5.355859              F
#
#     TEAM_CITY
# 0      Dallas
# ...

# %%
dal_selected_players = ['Kyrie Irving', 'Josh Green','Luka Doncic','Dwight Powell','Reggie Bullock']
dal_filtered_df = new_df[new_df['PLAYER_NAME'].isin(dal_selected_players)]
dal_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID     PLAYER_NAME   PTS_pred START_POSITION TEAM_CITY
# 7    1610612742     202681    Kyrie Irving  24.365069              G    Dallas
# 69   1610612742     203493  Reggie Bullock   9.552493              F    Dallas
# 166  1610612742     203939   Dwight Powell   7.004571              C    Dallas
# 253  1610612742    1629029     Luka Doncic  21.868238              G    Dallas
# 317  1610612742    1630182      Josh Green   5.355859              F    Dallas

# %%
dal_filtered_df['PTS_pred'].sum()
# Out:
# 68.14622948756487

# %%
gameid_22201167 = pd.concat([atl_filtered_df, dal_filtered_df])
gameid_22201167.to_csv('gameid_22201167.csv', index=False)

# %%
gameid_22201167
# Out:
#         TEAM_ID  PLAYER_ID      PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612737     203991     Clint Capela   9.427203              C
# 71   1610612737    1627749  Dejounte Murray  10.412616              G
# 144  1610612737    1628381     John Collins  22.443116              F
# 219  1610612737    1629027       Trae Young  20.914669              G
# 373  1610612737    1630180       Saddiq Bey   9.164724              F
# 7    1610612742     202681     Kyrie Irving  24.365069              G
# 69   1610612742     203493   Reggie Bullock   9.552493              F
# 166  1610612742     203939    Dwight Powell   7.004571              C
# 253  1610612742    1629029      Luka Doncic  21.868238              G
# 317  1610612742    1630182       Josh Green   5.355859              F
#
#     TEAM_CITY
# 0     Atlanta
# 71    Atlanta
# 144   Atlanta
# 219   Atlanta
# 373   Atlanta
# 7      Dallas
# 69     Dallas
# 166    Dallas
# 253    Dallas
# 317    Dallas

# %%
MEM_selected_players = ['Ja Morant','Desmond Bane','Dillon Brooks','Jaren Jackson Jr.','Xavier Tillman']

CHI_selected_players = ['Patrick Beverley','Zach LaVine','DeMar DeRozan','Patrick Williams','Nikola Vucevic']

# %%
MEM = pd.read_csv('FInal Files/MEM_MEMVSCHI_GAMEID22201165.csv')
CHI = pd.read_csv('FInal Files/CHI_MEMVSCHI_GAMEID22201165.csv')

# %%
merged = MEM.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

MEM_filtered_df = new_df[new_df['PLAYER_NAME'].isin(MEM_selected_players)]
MEM_filtered_df = MEM_filtered_df.drop('TOTAL', axis=1)
MEM_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred START_POSITION  \
# 28   1610612763    1628415      Dillon Brooks  16.896080              F
# 99   1610612763    1628991  Jaren Jackson Jr.  16.947080              F
# 160  1610612763    1629630          Ja Morant  20.497865              G
# 240  1610612763    1630214     Xavier Tillman   5.273916              C
# 274  1610612763    1630217       Desmond Bane  12.469576              G
#
#     TEAM_CITY
# 28    Memphis
# 99    Memphis
# 160   Memphis
# 240   Memphis
# 274   Memphis

# %%
merged = CHI.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

CHI_filtered_df = new_df[new_df['PLAYER_NAME'].isin(CHI_selected_players)]
CHI_filtered_df = CHI_filtered_df.drop('TOTAL', axis=1)
CHI_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612741     201942     DeMar DeRozan  17.394943              F
# 73   1610612741     201976  Patrick Beverley   9.050657              G
# 108  1610612741     202696    Nikola Vucevic  14.885595              C
# 188  1610612741     203897       Zach LaVine  19.969929              G
# 299  1610612741    1630172  Patrick Williams   4.966785              F
#
#     TEAM_CITY
# 0     Chicago
# 73    Chicago
# 108   Chicago
# 188   Chicago
# 299   Chicago

# %%
gameid_22201165 = pd.concat([CHI_filtered_df, MEM_filtered_df])
gameid_22201165.to_csv('gameid_22201165.csv', index=False)

# %%
gameid_22201165
# Out:
#         TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612741     201942      DeMar DeRozan  17.394943              F
# 73   1610612741     201976   Patrick Beverley   9.050657              G
# 108  1610612741     202696     Nikola Vucevic  14.885595              C
# 188  1610612741     203897        Zach LaVine  19.969929              G
# 299  1610612741    1630172   Patrick Williams   4.966785              F
# 28   1610612763    1628415      Dillon Brooks  16.896080              F
# 99   1610612763    1628991  Jaren Jackson Jr.  16.947080              F
# 160  1610612763    1629630          Ja Morant  20.497865              G
# 240  1610612763    1630214     Xavier Tillman   5.273916              C
# 274  1610612763    1630217       Desmond Bane  12.469576              G
#
#     TEAM_CITY
# 0     Chicago
# 73    Chicago
# 108   Chicago
# 188   Chicago
# 299   Chicago
# 28    Memphis
# 99    Memphis
# 160   Memphis
# 240   Memphis
# 274   Memphis

# %% [markdown]
# # PORTLAND VS. MINNESOTA

# %%
POR_selected_players = ['Damian Lillard','Anfernee Simons','Cam Reddish','Matisse Thybulle','Jusuf Nurkic']
MIN_selected_players = ['Mike Conley','Anthony Edwards','Kyle Anderson','Jaden McDaniels','Rudy Gobert']

# %%
POR = pd.read_csv('FInal Files/POR_PORVSMIN_GAMEID22201166.csv')
MIN = pd.read_csv('FInal Files/MIN_PORVSMINGAMEID22201166.csv')

# %%
merged = POR.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

POR_filtered_df = new_df[new_df['PLAYER_NAME'].isin(POR_selected_players)]
POR_filtered_df = POR_filtered_df.drop('TOTAL', axis=1)
POR_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612757     203081    Damian Lillard  25.185782              G
# 58   1610612757     203994      Jusuf Nurkic  13.201380              C
# 116  1610612757    1629014   Anfernee Simons  14.915831              G
# 205  1610612757    1629629       Cam Reddish   9.814327              F
# 229  1610612757    1629680  Matisse Thybulle   4.363765              F
#
#     TEAM_CITY
# 0    Portland
# 58   Portland
# 116  Portland
# 205  Portland
# 229  Portland

# %%
merged = MIN.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

MIN_filtered_df = new_df[new_df['PLAYER_NAME'].isin(MIN_selected_players)]
MIN_filtered_df = MIN_filtered_df.drop('TOTAL', axis=1)
MIN_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID      PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612750     201144      Mike Conley  14.996711              G
# 74   1610612750     203497      Rudy Gobert  12.313281              C
# 142  1610612750     203937    Kyle Anderson   6.546758              F
# 268  1610612750    1630162  Anthony Edwards  25.314321              G
# 345  1610612750    1630183  Jaden McDaniels   7.268205              F
#
#      TEAM_CITY
# 0    Minnesota
# 74   Minnesota
# 142  Minnesota
# 268  Minnesota
# 345  Minnesota

# %%
gameid_22201166 = pd.concat([MIN_filtered_df, POR_filtered_df])
gameid_22201166.to_csv('gameid_22201166.csv', index=False)
gameid_22201166
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 0    1610612750     201144       Mike Conley  14.996711              G
# 74   1610612750     203497       Rudy Gobert  12.313281              C
# 142  1610612750     203937     Kyle Anderson   6.546758              F
# 268  1610612750    1630162   Anthony Edwards  25.314321              G
# 345  1610612750    1630183   Jaden McDaniels   7.268205              F
# 0    1610612757     203081    Damian Lillard  25.185782              G
# 58   1610612757     203994      Jusuf Nurkic  13.201380              C
# 116  1610612757    1629014   Anfernee Simons  14.915831              G
# 205  1610612757    1629629       Cam Reddish   9.814327              F
# 229  1610612757    1629680  Matisse Thybulle   4.363765              F
#
#      TEAM_CITY
# 0    Minnesota
# 74   Minnesota
# 142  Minnesota
# 268  Minnesota
# 345  Minnesota
# 0     Portland
# 58    Portland
# 116   Portland
# 205   Portland
# 229   Portland

# %% [markdown]
# # CHARLOTTE VS TORONTO

# %%
TOR = pd.read_csv('FInal Files/TOR_CHAVSTORGAMEID22201163.csv')
CHA = pd.read_csv('FInal Files/CHA_CHAVSTORGAMEID22201163.csv')

# %%
CHA_selected_players = ['Dennis Smith Jr.','Terry Rozier','Svi Mykhailiuk','Theo Maledon','JT Thor']
TOR_selected_players = ['1628384','1627783','1630567','1627832','1627751']

# %%
CHA
# Out:
#        TEAM_ID  PLAYER_ID       PLAYER_NAME      PTS_pred
# 0   1610612766     202330    Gordon Hayward  1.332625e+01
# 1   1610612766    1626162   Kelly Oubre Jr.  8.845323e+00
# 2   1610612766    1626179      Terry Rozier  1.234788e+01
# 3   1610612766    1628372  Dennis Smith Jr.  9.522136e+00
# 4   1610612766    1629004    Svi Mykhailiuk  1.084715e+01
# 5   1610612766    1629023   P.J. Washington  1.011384e+01
# 6   1610612766    1630177      Theo Maledon  1.069988e+01
# 7   1610612766    1630208     Nick Richards  1.615573e+00
# 8   1610612766    1630270      Xavier Sneed -2.709700e-15
# 9   1610612766    1630539         Kai Jones  2.000000e+00
# 10  1610612766    1630547   James Bouknight  1.800000e+01
# 11  1610612766    1630550           JT Thor  5.932099e+00

# %%
merged = TOR.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

TOR_filtered_df = new_df[new_df['PLAYER_ID'].isin(TOR_selected_players)]
#TOR_filtered_df = TOR_filtered_df.drop('TOTAL', axis=1)
TOR_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID     PLAYER_NAME   PTS_pred START_POSITION TEAM_CITY
# 11   1610612761    1627751    Jakob Poeltl   6.125414              C   Toronto
# 54   1610612761    1627783   Pascal Siakam  11.921018              F   Toronto
# 134  1610612761    1627832   Fred VanVleet  11.959619              G   Toronto
# 202  1610612761    1628384    O.G. Anunoby  12.196268              F   Toronto
# 327  1610612761    1630567  Scottie Barnes  21.500000              G   Toronto

# %%
merged = CHA.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

CHA_filtered_df = new_df[new_df['PLAYER_NAME'].isin(CHA_selected_players)]
#TOR_filtered_df = TOR_filtered_df.drop('TOTAL', axis=1)
CHA_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 90   1610612766    1626179      Terry Rozier  12.347885              G
# 153  1610612766    1628372  Dennis Smith Jr.   9.522136              G
# 168  1610612766    1629004    Svi Mykhailiuk  10.847146              G
# 247  1610612766    1630177      Theo Maledon  10.699877              G
# 270  1610612766    1630550           JT Thor   5.932099              F
#
#      TEAM_CITY
# 90   Charlotte
# 153  Charlotte
# 168  Charlotte
# 247  Charlotte
# 270  Charlotte

# %%
gameid_22201163 = pd.concat([TOR_filtered_df, CHA_filtered_df])
gameid_22201163.to_csv('gameid_22201163.csv', index=False)
gameid_22201163
# Out:
#         TEAM_ID  PLAYER_ID       PLAYER_NAME   PTS_pred START_POSITION  \
# 11   1610612761    1627751      Jakob Poeltl   6.125414              C
# 54   1610612761    1627783     Pascal Siakam  11.921018              F
# 134  1610612761    1627832     Fred VanVleet  11.959619              G
# 202  1610612761    1628384      O.G. Anunoby  12.196268              F
# 327  1610612761    1630567    Scottie Barnes  21.500000              G
# 90   1610612766    1626179      Terry Rozier  12.347885              G
# 153  1610612766    1628372  Dennis Smith Jr.   9.522136              G
# 168  1610612766    1629004    Svi Mykhailiuk  10.847146              G
# 247  1610612766    1630177      Theo Maledon  10.699877              G
# 270  1610612766    1630550           JT Thor   5.932099              F
#
#      TEAM_CITY
# 11     Toronto
# 54     Toronto
# 134    Toronto
# 202    Toronto
# 327    Toronto
# 90   Charlotte
# 153  Charlotte
# 168  Charlotte
# 247  Charlotte
# 270  Charlotte

# %% [markdown]
# # UTA @ BKN

# %%
UTA = pd.read_csv('FInal Files/UTA_UTAVSBKNGAMEID22201163.csv')
BKN = pd.read_csv('FInal Files/BKN_UTAVSBKNGAMEID22201163.csv')

# %%
UTA
# Out:
#       TEAM_ID  PLAYER_ID            PLAYER_NAME   PTS_pred
# 0  1610612762     200752               Rudy Gay  14.523943
# 1  1610612762     203482           Kelly Olynyk   9.127185
# 2  1610612762    1627739              Kris Dunn  10.651701
# 3  1610612762    1627745           Damian Jones   9.078839
# 4  1610612762    1628374        Lauri Markkanen  14.935240
# 5  1610612762    1628962         Udoka Azubuike   5.488372
# 6  1610612762    1629308  Juan Toscano-Anderson   3.641207
# 7  1610612762    1629659    Talen Horton-Tucker   8.561102
# 8  1610612762    1629677           Luka Samanic   3.093625
# 9  1610612762    1629714       Jarrell Brantley   2.379607

# %%
UTA_selected_players = UTA.iloc[[2, 4, 5, 6, 7]]
BKN_selected_players = BKN.iloc[0:5]

# %%
UTA_selected_players['TEAM_CITY'] = 'Utah'
# Out:
# C:\Users\micha\anaconda3\envs\CSE6242\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
UTA_selected_players
# Out:
#       TEAM_ID  PLAYER_ID            PLAYER_NAME   PTS_pred TEAM_CITY
# 2  1610612762    1627739              Kris Dunn  10.651701      Utah
# 4  1610612762    1628374        Lauri Markkanen  14.935240      Utah
# 5  1610612762    1628962         Udoka Azubuike   5.488372      Utah
# 6  1610612762    1629308  Juan Toscano-Anderson   3.641207      Utah
# 7  1610612762    1629659    Talen Horton-Tucker   8.561102      Utah

# %%
merged = BKN.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

BKN_filtered_df = new_df[new_df['PLAYER_NAME'].isin(BKN_selected_players)]
#TOR_filtered_df = TOR_filtered_df.drop('TOTAL', axis=1)
BKN_filtered_df
# Out:
#       TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred START_POSITION  \
# 9  1610612751     203915  Spencer Dinwiddie  14.846963              G
#
#   TEAM_CITY
# 9  Brooklyn

# %%
BKN_selected_players['TEAM_CITY'] = 'Brooklyn'
# Out:
# C:\Users\micha\anaconda3\envs\CSE6242\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
BKN_selected_players
# Out:
#       TEAM_ID  PLAYER_ID        PLAYER_NAME   PTS_pred TEAM_CITY
# 0  1610612751     201988        Patty Mills   7.737229  Brooklyn
# 1  1610612751     202693    Markieff Morris   9.097858  Brooklyn
# 2  1610612751     203552         Seth Curry   9.665547  Brooklyn
# 3  1610612751     203915  Spencer Dinwiddie  14.846963  Brooklyn
# 4  1610612751     203925         Joe Harris   6.304905  Brooklyn

# %%
gameid_22201164 = pd.concat([UTA_selected_players, BKN_selected_players])
gameid_22201164.to_csv('gameid_22201164.csv', index=False)
gameid_22201164
# Out:
#       TEAM_ID  PLAYER_ID            PLAYER_NAME   PTS_pred TEAM_CITY
# 2  1610612762    1627739              Kris Dunn  10.651701      Utah
# 4  1610612762    1628374        Lauri Markkanen  14.935240      Utah
# 5  1610612762    1628962         Udoka Azubuike   5.488372      Utah
# 6  1610612762    1629308  Juan Toscano-Anderson   3.641207      Utah
# 7  1610612762    1629659    Talen Horton-Tucker   8.561102      Utah
# 0  1610612751     201988            Patty Mills   7.737229  Brooklyn
# 1  1610612751     202693        Markieff Morris   9.097858  Brooklyn
# 2  1610612751     203552             Seth Curry   9.665547  Brooklyn
# 3  1610612751     203915      Spencer Dinwiddie  14.846963  Brooklyn
# 4  1610612751     203925             Joe Harris   6.304905  Brooklyn

# %% [markdown]
# # WAS @ NYK

# %%
WAS = pd.read_csv('FInal Files/WAS_WASVSNYKGAMEID22201168.csv')
NYK = pd.read_csv('FInal Files/NYK_WASVSNYKGAMEID22201168.csv')

# %%
WAS_selected_players = ['Delon Wright','Johnny Davis','Corey Kispert','Anthony Gill','Daniel Gafford']

# %%
merged = WAS.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

WAS_filtered_df = new_df[new_df['PLAYER_NAME'].isin(WAS_selected_players)]
#TOR_filtered_df = TOR_filtered_df.drop('TOTAL', axis=1)
WAS_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID     PLAYER_NAME      PTS_pred START_POSITION  \
# 117  1610612764    1626153    Delon Wright  6.162476e+00              G
# 256  1610612764    1629655  Daniel Gafford  7.615990e+00              C
# 342  1610612764    1630264    Anthony Gill  1.334343e+00              F
# 349  1610612764    1630557   Corey Kispert  1.070677e+01              F
# 400  1610612764    1631098    Johnny Davis  1.332268e-15              G
#
#       TEAM_CITY
# 117  Washington
# 256  Washington
# 342  Washington
# 349  Washington
# 400  Washington

# %%
NYK_selected_players = ['Immanuel Quickley','Quentin Grimes','RJ Barrett','Obi Toppin','Isaiah Hartenstein']

# %%
merged = NYK.merge(df[['PLAYER_ID', 'START_POSITION','TEAM_CITY']], on='PLAYER_ID', how='inner')
merged['START_POSITION'] = merged['START_POSITION'].fillna('Unknown')

new_df = merged.drop_duplicates(subset=['PLAYER_ID'])
#new_df = new_df.drop('TOTAL', axis=1)

NYK_filtered_df = new_df[new_df['PLAYER_NAME'].isin(NYK_selected_players)]
#TOR_filtered_df = TOR_filtered_df.drop('TOTAL', axis=1)
NYK_filtered_df
# Out:
#         TEAM_ID  PLAYER_ID         PLAYER_NAME   PTS_pred START_POSITION  \
# 77   1610612752    1628392  Isaiah Hartenstein   5.352747              C
# 267  1610612752    1629628          RJ Barrett  16.954417              F
# 358  1610612752    1629656      Quentin Grimes   4.082813              F
# 427  1610612752    1630167          Obi Toppin   8.058256              F
# 430  1610612752    1630193   Immanuel Quickley  13.481928              G
#
#     TEAM_CITY
# 77   New York
# 267  New York
# 358  New York
# 427  New York
# 430  New York

# %%
gameid_22201168 = pd.concat([NYK_filtered_df, WAS_filtered_df])
gameid_22201168.to_csv('gameid_22201168.csv', index=False)
gameid_22201168
# Out:
#         TEAM_ID  PLAYER_ID         PLAYER_NAME      PTS_pred START_POSITION  \
# 77   1610612752    1628392  Isaiah Hartenstein  5.352747e+00              C
# 267  1610612752    1629628          RJ Barrett  1.695442e+01              F
# 358  1610612752    1629656      Quentin Grimes  4.082813e+00              F
# 427  1610612752    1630167          Obi Toppin  8.058256e+00              F
# 430  1610612752    1630193   Immanuel Quickley  1.348193e+01              G
# 117  1610612764    1626153        Delon Wright  6.162476e+00              G
# 256  1610612764    1629655      Daniel Gafford  7.615990e+00              C
# 342  1610612764    1630264        Anthony Gill  1.334343e+00              F
# 349  1610612764    1630557       Corey Kispert  1.070677e+01              F
# 400  1610612764    1631098        Johnny Davis  1.332268e-15              G
#
#       TEAM_CITY
# 77     New York
# 267    New York
# 358    New York
# 427    New York
# 430    New York
# 117  Washington
# ...
